# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
df=pd.read_csv("happinessindex.csv")

# %%
pd.set_option("display.max_rows",None)

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df=df.rename(columns={"Economy (GDP per Capita)":"Economy","Health (Life Expectancy)":"Health","Trust (Government Corruption)":"Trust","Happiness Score":"Happiness_Score","Dystopia Residual":"Dystopia_Residual"})
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness_Score',
#        'Standard Error', 'Economy', 'Family', 'Health', 'Freedom', 'Trust',
#        'Generosity', 'Dystopia_Residual'],
#       dtype='object')

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness_Score  Standard Error  Economy   Family   Health  Freedom  \
# 153            3.465         0.03464  0.22208  0.77370  0.42864  0.59201
# 154            3.340         0.03656  0.28665  0.35386  0.31910  0.48450
# 155            3.006         0.05015  0.66320  0.47489  0.72193  0.15684
# 156            2.905         0.08658  0.01530  0.41587  0.22396  0.11850
# 157            2.839         0.06727  0.20868  0.13995  0.28443  0.36453
#
#        Trust  Generosity  Dystopia_Residual
# 153  0.55191     0.22628            0.67042
# 154  0.08010     0.18260            1.63328
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
# Country              158 non-null object
# Region               158 non-null object
# Happiness Rank       158 non-null int64
# Happiness_Score      158 non-null float64
# Standard Error       158 non-null float64
# Economy              158 non-null float64
# Family               158 non-null float64
# Health               158 non-null float64
# Freedom              158 non-null float64
# Trust                158 non-null float64
# Generosity           158 non-null float64
# Dystopia_Residual    158 non-null float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness_Score  Standard Error     Economy  \
# count      158.000000       158.000000      158.000000  158.000000
# mean        79.493671         5.375734        0.047885    0.846137
# std         45.754363         1.145010        0.017146    0.403121
# min          1.000000         2.839000        0.018480    0.000000
# 25%         40.250000         4.526000        0.037268    0.545808
# 50%         79.500000         5.232500        0.043940    0.910245
# 75%        118.750000         6.243750        0.052300    1.158448
# max        158.000000         7.587000        0.136930    1.690420
#
#            Family      Health     Freedom       Trust  Generosity  \
# count  158.000000  158.000000  158.000000  158.000000  158.000000
# mean     0.991046    0.630259    0.428615    0.143422    0.237296
# std      0.272369    0.247078    0.150693    0.120034    0.126685
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Country              0
# Region               0
# Happiness Rank       0
# Happiness_Score      0
# Standard Error       0
# Economy              0
# Family               0
# Health               0
# Freedom              0
# Trust                0
# Generosity           0
# Dystopia_Residual    0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.isnull())
plt.title("null value")
plt.show()

# %%
df['Happiness_Score'].head(10).plot(xticks=np.arange(9), kind='barh', figsize= (10, 10))
plt.xlabel("Happiness Score")
plt.title('Happiness Score of the top 10 Countries')
plt.show()

# %%
sns.distplot(df["Standard Error"])
# Out:
# C:\Python 2\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness_Score',
#        'Standard Error', 'Economy', 'Family', 'Health', 'Freedom', 'Trust',
#        'Generosity', 'Dystopia_Residual'],
#       dtype='object')

# %%
sns.distplot(df["Economy"])
# Out:
# C:\Python 2\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df["Family"])
# Out:
# C:\Python 2\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df["Health"])
# Out:
# C:\Python 2\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df["Freedom"])
# Out:
# C:\Python 2\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df["Trust"])
# Out:
# C:\Python 2\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df["Generosity"])
# Out:
# C:\Python 2\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df['Dystopia_Residual'])
# Out:
# C:\Python 2\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df=df.drop(columns=['Country','Region','Happiness Rank',"Standard Error"])

# %%
df.head()
# Out:
#    Happiness_Score  Economy   Family   Health  Freedom    Trust  Generosity  \
# 0            7.587  1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# 1            7.561  1.30232  1.40223  0.94784  0.62877  0.14145     0.43630
# 2            7.527  1.32548  1.36058  0.87464  0.64938  0.48357     0.34139
# 3            7.522  1.45900  1.33095  0.88521  0.66973  0.36503     0.34699
# 4            7.427  1.32629  1.32261  0.90563  0.63297  0.32957     0.45811
#
#    Dystopia_Residual
# 0            2.51738
# 1            2.70201
# 2            2.49204
# 3            2.46531
# 4            2.45176

# %%
for i in df.columns:
    print(df[i].value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
# 5      7.406
# 6      7.378
# 7      7.364
# 8      7.286
# 9      7.284
# 10     7.278
# 11     7.226
# 12     7.200
# 13     7.187
# 14     7.119
# 15     6.983
# 16     6.946
# 17     6.940
# 18     6.937
# 19     6.901
# 20     6.867
# 21     6.853
# 22     6.810
# 23     6.798
# 24     6.786
# 25     6.750
# 26     6.670
# 27     6.611
# 28     6.575
# 29     6.574
# 30     6.505
# 31     6.485
# 32     6.477
# 33     6.455
# 34     6.411
# 35     6.329
# 36     6.302
# 37     6.298
# 38     6.295
# 39     6.269
# 40     6.168
# 41     6.130
# 42     6.123
# 43     6.003
# 44     5.995
# 45     5.987
# 46     5.984
# 47     5.975
# 48     5.960
# 49     5.948
# 50     5.890
# 51     5.889
# 52     5.878
# 53     5.855
# 54     5.848
# 55     5.833
# 56     5.828
# 57     5.824
# 58     5.813
# 59     5.791
# 60     5.770
# 61     5.759
# 62     5.754
# ...

# %%
np.count_nonzero(df)
# Out:
# 1258

# %%
total_values=158*8
print(total_values)
# Out:
# 1264

# %%
(df==0).sum()
# Out:
# Happiness_Score      0
# Economy              1
# Family               1
# Health               1
# Freedom              1
# Trust                1
# Generosity           1
# Dystopia_Residual    0
# dtype: int64

# %%
df.skew()
# Out:
# Happiness_Score      0.097769
# Economy             -0.317575
# Family              -1.006893
# Health              -0.705328
# Freedom             -0.413462
# Trust                1.385463
# Generosity           1.001961
# Dystopia_Residual   -0.238911
# dtype: float64

# %%
#economy,Freedom is not skewed so we replace with mean
##Family,Health,Trust,Generosity is skewed so we can replace with median

# %%
df["Economy"]=df["Economy"].replace(0,df["Economy"].mean())

# %%
(df["Economy"]==0).sum()
# Out:
# 0

# %%
df["Freedom"]=df["Freedom"].replace(0,df["Freedom"].mean())

# %%
(df["Freedom"]==0).sum()
# Out:
# 0

# %%
df["Family"]=df["Family"].replace(0,df["Family"].median())

# %%
(df["Family"]==0).sum()
# Out:
# 0

# %%
df["Health"]=df["Health"].replace(0,df["Health"].median())

# %%
(df["Health"]==0).sum()
# Out:
# 0

# %%
df["Trust"]=df["Trust"].replace(0,df["Trust"].median())

# %%
(df["Trust"]==0).sum()
# Out:
# 0

# %%
df["Generosity"]=df["Generosity"].replace(0,df["Generosity"].median())

# %%
(df["Generosity"]==0).sum()
# Out:
# 0

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
z
# Out:
# array([[1.93736005, 1.37586008, 1.35499019, ..., 2.31388874, 0.46542331,
#         0.75825809],
#        [1.91458063, 1.13808374, 1.55796066, ..., 0.02224623, 1.58276123,
#         1.09285682],
#        [1.88479215, 1.19654961, 1.39760937, ..., 2.84930372, 0.82267994,
#         0.71233526],
#        ...,
#        [2.0761992 , 0.47533182, 2.01227136, ..., 0.37736354, 1.86698086,
#         3.20843049],
#        [2.1646885 , 2.1109119 , 2.23949664, ..., 0.36494874, 0.33149681,
#         0.48198451],
#        [2.22251319, 1.62273707, 3.30178061, ..., 0.3087969 , 0.57543397,
#         0.96361241]])

# %%
#threshold is 3
np.where(z>3)
# Out:
# (array([ 27, 128, 153, 155, 157], dtype=int64),
#  array([5, 6, 5, 7, 2], dtype=int64))

# %%
df=df[(z<3).all(axis=1)]

# %%
plt.figure(figsize=(20,30),facecolor="white")
plotnumber=1
for column in df:
    if plotnumber<=10:
       ax=plt.subplot(5,3,plotnumber)
       sns.boxplot(df)
       plt.xlabel(column,fontsize=20)
       plt.ylabel("chanceofadmit",fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
df.shape
# Out:
# (153, 8)

# %%
df.head()
# Out:
#    Happiness_Score  Economy   Family   Health  Freedom    Trust  Generosity  \
# 0            7.587  1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# 1            7.561  1.30232  1.40223  0.94784  0.62877  0.14145     0.43630
# 2            7.527  1.32548  1.36058  0.87464  0.64938  0.48357     0.34139
# 3            7.522  1.45900  1.33095  0.88521  0.66973  0.36503     0.34699
# 4            7.427  1.32629  1.32261  0.90563  0.63297  0.32957     0.45811
#
#    Dystopia_Residual
# 0            2.51738
# 1            2.70201
# 2            2.49204
# 3            2.46531
# 4            2.45176

# %%
##bivariante analysis
plt.scatter(df["Happiness_Score"],df["Economy"],alpha=0.5,c=(0,0,0),edgecolors="red")
plt.title("Happiness Score vs Economy")
plt.show()

# %%
plt.scatter(df["Happiness_Score"],df["Family"],alpha=0.5,c=(0,0,0),edgecolors="red")
plt.title("Happiness Score vs Family")
plt.show()

# %%
plt.scatter(df["Happiness_Score"],df["Health"],alpha=0.5,c=(0,0,0),edgecolors="red")
plt.title("Happiness Score vs Health")
plt.show()

# %%
plt.scatter(df["Happiness_Score"],df["Freedom"],alpha=0.5,c=(0,0,0),edgecolors="red")
plt.title("Happiness Score vs Freedom")
plt.show()

# %%
plt.scatter(df["Happiness_Score"],df["Trust"],alpha=0.5,c=(0,0,0),edgecolors="red")
plt.title("Happiness Score vs Trust")
plt.show()

# %%
plt.scatter(df["Happiness_Score"],df["Generosity"],alpha=0.5,c=(0,0,0),edgecolors="red")
plt.title("Happiness Score vs Generosity")
plt.show()

# %%
plt.scatter(df["Happiness_Score"],df["Dystopia_Residual"],alpha=0.5,c=(0,0,0),edgecolors="red")
plt.title("Happiness Score vs Dystopia Residual")
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
corr=df.corr()
print(corr)
# Out:
#                    Happiness_Score   Economy    Family    Health   Freedom  \
# Happiness_Score           1.000000  0.777179  0.716220  0.734855  0.582841
# Economy                   0.777179  1.000000  0.630651  0.794796  0.378346
# Family                    0.716220  0.630651  1.000000  0.502949  0.478901
# Health                    0.734855  0.794796  0.502949  1.000000  0.386551
# Freedom                   0.582841  0.378346  0.478901  0.386551  1.000000
# Trust                     0.471249  0.337150  0.252445  0.272904  0.508490
# Generosity                0.246379  0.034377  0.153215  0.137784  0.407605
# Dystopia_Residual         0.500564  0.016170  0.112334  0.017455  0.050680
#
#                       Trust  Generosity  Dystopia_Residual
# Happiness_Score    0.471249    0.246379           0.500564
# Economy            0.337150    0.034377           0.016170
# Family             0.252445    0.153215           0.112334
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(corr,annot=True)
plt.show()

# %%
df.skew()
# Out:
# Happiness_Score      0.167190
# Economy             -0.391106
# Family              -0.819533
# Health              -0.721554
# Freedom             -0.339947
# Trust                1.308944
# Generosity           0.688169
# Dystopia_Residual   -0.057950
# dtype: float64

# %%
x=df.drop("Happiness_Score",axis=1)
y=df.Happiness_Score

# %%
from  sklearn.preprocessing import power_transform
x_new=power_transform(x)
x_new=pd.DataFrame(x_new)
x_new.columns=["Economy","Family","Health","Freedom","Trust","Generosity","Dystopia_Residual"]
x_new.head()
# Out:
#     Economy    Family    Health   Freedom     Trust  Generosity  \
# 0  1.501150  1.674179  1.486909  1.765355  1.825352    0.663177
# 1  1.202443  2.029068  1.528589  1.450830  0.357199    1.576304
# 2  1.275064  1.747017  1.070128  1.625761  1.954842    0.986657
# 3  1.704225  1.554031  1.133986  1.801534  1.677821    1.024985
# 4  1.277614  1.500840  1.259572  1.486227  1.558453    1.695620
#
#    Dystopia_Residual
# 0           0.735763
# 1           1.096249
# 2           0.686464
# 3           0.634509
# 4           0.608191

# %%
x_new.skew()
# Out:
# Economy             -0.141079
# Family              -0.147023
# Health              -0.181622
# Freedom             -0.072807
# Trust                0.183042
# Generosity           0.028895
# Dystopia_Residual    0.012758
# dtype: float64

# %%
y.head()
# Out:
# 0    7.587
# 1    7.561
# 2    7.527
# 3    7.522
# 4    7.427
# Name: Happiness_Score, dtype: float64

# %%
x_new.shape
# Out:
# (153, 7)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
x_scaler=scaler.fit_transform(x_new)
x_scaler
print(x_scaler.shape)
print(y.shape)
# Out:
# (153, 7)
# (153,)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
max_r_score=0
final_r_state=0
for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x_scaler, y,test_size=0.30,random_state = i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    y_pred =lr.predict(x_test)
    r2_scr=r2_score(y_pred,y_test)
    print("r2 score corresponding to ",i," is ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=i
print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
# Out:
# r2 score corresponding to  1  is  0.9379020735085553
# r2 score corresponding to  2  is  0.9926448577044527
# r2 score corresponding to  3  is  0.9830874438025734
# r2 score corresponding to  4  is  0.9865454593049074
# r2 score corresponding to  5  is  0.969155623148286
# r2 score corresponding to  6  is  0.9679495631584715
# r2 score corresponding to  7  is  0.9530970003498348
# r2 score corresponding to  8  is  0.9567043756412746
# r2 score corresponding to  9  is  0.9652613268916522
# r2 score corresponding to  10  is  0.9589190140785128
# r2 score corresponding to  11  is  0.957443669812027
# r2 score corresponding to  12  is  0.9919365648363644
# r2 score corresponding to  13  is  0.9882600289008526
# r2 score corresponding to  14  is  0.9694826921518976
# r2 score corresponding to  15  is  0.985070760018214
# r2 score corresponding to  16  is  0.9884687086702074
# r2 score corresponding to  17  is  0.9898308230588903
# r2 score corresponding to  18  is  0.9788987131826887
# ...

# %%
##so at random state 178 we have max r2_score

# %%
##so using linear regression for random state 126
x_train, x_test, y_train, y_test = train_test_split(x_scaler, y,test_size=0.20,random_state =178)

def eval(model):
    model.fit(x_train,y_train)
    y_pred =model.predict(x_test)
    r2_scr=r2_score(y_pred,y_test)
    print(r2_scr)
    print(mean_squared_error(y_pred,y_test))
    print(mean_absolute_error(y_pred,y_test))

# %%
##Prediction for Linear Regression with random_state as 126
lr=LinearRegression()
eval(lr)
# Out:
# 0.9937876702760238
# 0.008058605417382571
# 0.07419185314653247

# %%
##We will use DecisionTreeRegressor with random_state as 126
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
eval(rfr)
# Out:
# 0.8848131849511398
# 0.10493666181935485
# 0.2587509677419355

# %%
## we will also use SupportVectorRegressor with random_state as 126
from sklearn.svm import SVR
svr=SVR()
eval(svr)
# Out:
# 0.9578209244066602
# 0.044971974335947164
# 0.1499759222075748

# %%
## we will use cross validation to avoid chance of overfitting
##we apply cross validation for linear regression
from sklearn.model_selection import cross_val_score
lor=LinearRegression()
val_score=cross_val_score(lor,x_scaler,y,cv=4,scoring="r2")
print(val_score.mean())
# Out:
# 0.6322119755019462

# %%
#Checking the cross validation score for RandomForest Regressor
rfr=RandomForestRegressor()
val_score=cross_val_score(rfr,x_scaler,y,cv=4,scoring="r2")
print(val_score.mean())
# Out:
# -3.95524025848035

# %%
##Checking the cross validation score for Supportvector Regressor
svr=SVR()
val_score=cross_val_score(svr,x_scaler,y,cv=4,scoring="r2")
print(val_score.mean())
# Out:
# -2.8303081872733946

# %%
##from the above croos_val_score of we can infer that Linear Regression the best model to proceed further
##We will try to tune parameters

# %%
from sklearn.model_selection import GridSearchCV
parameter={"fit_intercept":[True,False],"n_jobs":[1,None,1],"positive":[True,False]}

# %%
grid=GridSearchCV(estimator=lr,param_grid=parameter,cv=4)
grid.fit(x_scaler,y)
# Out:
# GridSearchCV(cv=4, estimator=LinearRegression(),
#              param_grid={'fit_intercept': [True, False], 'n_jobs': [1, None, 1],
#                          'positive': [True, False]})

# %%
grid.best_params_
# Out:
# {'fit_intercept': True, 'n_jobs': 1, 'positive': True}

# %%
grid.best_score_
# Out:
# 0.6322119755019471

# %%
#now lets fit the model using the best parameters
x_train, x_test, y_train, y_test = train_test_split(x_scaler, y,test_size=0.20,random_state =126)

lr=LinearRegression(fit_intercept=True,n_jobs=1,positive=True)

lr.fit(x_train,y_train)

print(lr.score(x_train,y_train))

pred=lr.predict(x_test)

r2_scr=r2_score(pred,y_test)

print(lr.score(x_test,y_test))

print("r2_score",r2_scr)

print("mean_squared_error",mean_squared_error(pred,y_test))

print("mean_absolute_error",mean_absolute_error(pred,y_test))
# Out:
# 0.9768665331388263
# 0.9928485395804105
# r2_score 0.9927929798145327
# mean_squared_error 0.010723433470865412
# mean_absolute_error 0.07637570147828081

# %%
import joblib

joblib.dump(lr,"happiness_score_pred.obj")
# Out:
# ['happiness_score_pred.obj']

# %%
pt_mod=joblib.load("happiness_score_pred.obj")
outcome=pt_mod.predict(x_test)
print(r2_score(outcome,y_test))
# Out:
# 0.9927929798145327

# %%
##Model is overfitting may be due to small dataset and multicollinearity
